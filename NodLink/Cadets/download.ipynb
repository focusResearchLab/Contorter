# %% [markdown]
# #### To download the trained models and preprocessed files you can run the following cell

# %%
import gdown

# Google Drive folder URL
folder_url = "https://drive.google.com/drive/folders/1IHLiI3vS60-2kuM0RyFwTXAUcd6RXXae"

# Download the entire folder
gdown.download_folder(
    url=folder_url,
    output="dependancies",  # local directory
    quiet=False,
    use_cookies=False
)
